# %% [markdown]
# # Python

# %% [markdown]
# """ python  ==> python is a general-parpose and high level programming language
# developed by Guido van Russom in feb 1991
#
# compailar ==> it is a translater used to human readable source code into machine level code
#
# type  ==> it is used to check the data
#
# Dynamically Typed  ==>  no need to declare variable type
#
# """
